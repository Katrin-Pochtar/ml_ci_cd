# %% [markdown]
# # **Семинар 2. Обнаружение дрифта данных и модели с помощью Evidently**
#
# ---
#
# ## **Цель семинара**
#
# Научиться анализировать и визуализировать изменения в данных и поведении ML-модели с помощью библиотеки **Evidently AI**.
#
# После занятия студент сможет:
#
# - определять дрифт данных (data drift) и дрифт модели (target drift);
# - строить интерактивные отчёты о дрифте;
# - интерпретировать статистические показатели (PSI, KS, p-value);
# - встраивать Evidently в пайплайн CI/CD для мониторинга моделей.
#
# ---

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# 1. Установка библиотек и импорт зависимостей

# !pip install pandas scikit-learn matplotlib

# %% [markdown]
# ## **2. Подготовка данных**
#
# Создадим два датафрейма:
# - `reference_data` — исторические (тренировочные) данные;
# - `current_data` — новые данные из продакшена.
#
# На практике дрифт возникает, если распределение признаков во «входящих» данных начинает отличаться от обучающего.

# %%
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np

# Загружаем базовый датасет
iris = load_iris(as_frame=True)
ref_df = iris.frame.copy()

# Создаём "текущие" данные с дрифтом
cur_df = ref_df.copy()
cur_df["sepal length (cm)"] = cur_df["sepal length (cm)"] * np.random.uniform(0.8, 1.2, len(cur_df))
cur_df["petal width (cm)"] = cur_df["petal width (cm)"] + np.random.normal(0, 0.3, len(cur_df))

# Добавляем небольшой сдвиг в распределении target
cur_df["target"] = cur_df["target"].apply(lambda x: 0 if np.random.rand() < 0.4 else x)

ref_df.head()
# Out:
# /var/folders/tn/pky4_jf56t74wlclcq15d9sc0000gn/T/ipykernel_10672/884291157.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## **3. Создание отчёта с Evidently**
#
# Evidently позволяет визуализировать изменения распределений признаков и целей между двумя выборками.

# %%
import numpy as np
print(f"NumPy version: {np.__version__}")
# Out:
# NumPy version: 1.26.4

# %%
# !pip install evidently
# Out:
# Requirement already satisfied: evidently in /opt/anaconda3/lib/python3.12/site-packages (0.3.2)
# Requirement already satisfied: plotly>=5.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (5.24.1)
# Requirement already satisfied: statsmodels>=0.12.2 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (0.14.6)
# Requirement already satisfied: scikit-learn>=0.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (1.8.0)
# Requirement already satisfied: pandas>=1.3.5 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (2.3.3)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (1.26.4)
# Requirement already satisfied: nltk>=3.6.7 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (3.9.2)
# Requirement already satisfied: umap-learn>=0.5.3 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (0.5.9.post2)
# Requirement already satisfied: scipy>=1.5.4 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (1.16.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (2.32.5)
# Requirement already satisfied: PyYAML>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (6.0.3)
# Requirement already satisfied: pydantic<2,>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from evidently) (1.10.24)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (8.3.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (2025.11.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.6.7->evidently) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.5->evidently) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.5->evidently) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.5->evidently) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotly>=5.5.0->evidently) (8.2.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from plotly>=5.5.0->evidently) (25.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<2,>=1.9->evidently) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evidently) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evidently) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evidently) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.19.0->evidently) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.24.0->evidently) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels>=0.12.2->evidently) (1.0.2)
# Requirement already satisfied: numba>=0.51.2 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn>=0.5.3->evidently) (0.63.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn>=0.5.3->evidently) (0.5.13)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.51.2->umap-learn>=0.5.3->evidently) (0.46.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->evidently) (1.17.0)

# %%
from evidently.metrics import DataDriftPreset, TargetDriftPreset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from evidently.metrics import DataDriftPreset, TargetDriftPreset
#
# ModuleNotFoundError: No module named 'evidently'

# %%
from evidently import metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from evidently import metrics
#
# ModuleNotFoundError: No module named 'evidently'

# %%
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset

report = Report(metrics=[
    DataDriftPreset(),
    TargetDriftPreset()
])

report.run(reference_data=ref_df, current_data=cur_df)
report.save_html("drift_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from evidently.report import Report
#       2 from evidently.metric_preset import DataDriftPreset, TargetDriftPreset
#       4 report = Report(metrics=[
#       5     DataDriftPreset(),
#       6     TargetDriftPreset()
#       7 ])
#
# ModuleNotFoundError: No module named 'evidently'

# %% [markdown]
# После выполнения появится файл **`drift_report.html`**,
# который можно открыть в браузере и увидеть:
# - гистограммы изменений признаков;
# - p-value для каждого признака;
# - общий индекс дрифта по датасету.

# %% [markdown]
# ## **4. Интерпретация отчёта**
#
# Обратите внимание на ключевые показатели:
#
# | **Метрика** | **Описание** |
# |--------------|--------------|
# | **PSI (Population Stability Index)** | Измеряет изменение распределения признака между reference и current. Значения > 0.25 — сильный дрифт. |
# | **KS (Kolmogorov–Smirnov)** | Тест на равенство распределений. p-value < 0.05 → признак изменился. |
# | **Share of drifted features** | Доля признаков, у которых зафиксирован дрифт. |
#
# Если доля «дрифтовых» признаков > 30 %, модель, вероятно, нуждается в переобучении.

# %%
import numpy as np

def psi_score (reference, current, n_bins=10, eps=1e-6):
  ref = np.asarray(reference).astype(float)
  cur = np.asarray(current).astype(float)

  ref = ref[~np.isnan(ref)]
  cur = cur[~np.isnan(cur)]

  bin_edges = np.histogram_bin_edges(ref, bins=n_bins)

  ref_counts = np.histogram(ref, bins=bin_edges)[0]
  cur_counts = np.histogram(cur, bins=bin_edges)[0]

  ref_perc = ref_counts / ref_counts.sum()
  cur_perc = cur_counts / cur_counts.sum()

  ref_perc = np.clip(ref_perc, eps,1.0)
  cur_perc = np.clip(cur_perc, eps,1.0)

  psi_components = (ref_perc - cur_perc) * np.log(ref_perc / cur_perc)
  total_psi = psi_components.sum()

  bin_table = {
      "bin_edges": bin_edges,
      "ref_counts": ref_counts,
      "cur_counts": cur_counts,
      "ref_perc": ref_perc,
      "cur_perc": cur_perc,
      "psi_components": psi_components
  }

  return float(total_psi), bin_table

# %%
ref = np.random.normal(loc=0, scale=1, size=1000)
cur = np.random.normal(loc=0.5, scale=1, size=1000)


psi_score, bin_table = psi_score(ref, cur)
print('PSI: ', psi_score)
print('Доля дрейф-компонент', bin_table["psi_components"])

# %%
import numpy as np

def psi_score (reference, current, n_bins=10, eps=1e-6):
  ref = np.asarray(reference).astype(float)
  cur = np.asarray(current).astype(float)

  ref = ref[~np.isnan(ref)]
  cur = cur[~np.isnan(cur)]

  bin_edges = np.histogram_bin_edges(ref, bins=n_bins)

  ref_counts = np.histogram(ref, bins=bin_edges)[0]
  cur_counts = np.histogram(cur, bins=bin_edges)[0]

  ref_perc = ref_counts / ref_counts.sum()
  cur_perc = cur_counts / cur_counts.sum()

  ref_perc = np.clip(ref_perc, eps,1.0)
  cur_perc = np.clip(cur_perc, eps,1.0)

  psi_components = (ref_perc - cur_perc) * np.log(ref_perc / cur_perc)
  total_psi = psi_components.sum()

  bin_table = {
      "bin_edges": bin_edges,
      "ref_counts": ref_counts,
      "cur_counts": cur_counts,
      "ref_perc": ref_perc,
      "cur_perc": cur_perc,
      "psi_components": psi_components
  }

  return float(total_psi), bin_table


ref = np.random.normal(loc=0, scale=1, size=1000)
cur = np.random.normal(loc=0.5, scale=1.7, size=1000)

psi_score, bin_table = psi_score(ref, cur)
print('PSI: ', psi_score)
print('Доля дрейф-компонент', bin_table["psi_components"])

# %% [markdown]
# ## **5. Добавление автоматического порога для оповещения**

# %%
drift_dict = report.as_dict()

# Проверяем общий статус дрифта по датасету
if drift_dict["metrics"][0]["result"]["dataset_drift"]:
    print("⚠️ Drift detected! Trigger retraining.")
else:
    print("✅ No significant drift detected.")

# %% [markdown]
# ## еще примеры

# %%
import pandas as pd
import numpy as np
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset

ref = pd.DataFrame({
    "city": np.random.choice(["Moscow", "SPB", "Kazan"], size=500)
})

cur = pd.DataFrame({
    "city": np.random.choice(["Moscow", "SPB", "Novosibirsk"], size=500)
})

report = Report(metrics=[DataDriftPreset()])
report.run(reference_data=ref, current_data=cur)
report.save_html("drift_report2.html")

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)

ref_df = df.copy()
cur_df = df.copy()

cur_df["sepal width (cm)"] *= 1.25  # drift только одного признака

report = Report(metrics=[DataDriftPreset()])
report.run(reference_data=ref_df, current_data=cur_df)
report.save_html("drift_report3.html")

# %%
ref = pd.DataFrame({
    "sales": np.random.normal(loc=100, scale=10, size=500),
    "month": np.random.choice(["Jan", "Feb", "Mar"], size=500)
})

cur = pd.DataFrame({
    "sales": np.random.normal(loc=150, scale=15, size=500),
    "month": np.random.choice(["Jun", "Jul", "Aug"], size=500)
})

report = Report(metrics=[DataDriftPreset()])
report.run(reference_data=ref, current_data=cur)
report.save_html('drift_report4.html')

# %%
ref_df = pd.DataFrame({
    "x": np.random.normal(0, 1, 400),
    "target": np.random.choice([0,1], 400, p=[0.8, 0.2])
})

cur_df = pd.DataFrame({
    "x": np.random.normal(1, 1.5, 400),
    "target": np.random.choice([0,1], 400, p=[0.5, 0.5])
})

from evidently.metric_preset import DataDriftPreset, TargetDriftPreset

report = Report(metrics=[DataDriftPreset(), TargetDriftPreset()])
report.run(reference_data=ref_df, current_data=cur_df)
report.save_html('drift_report5.html')

# %%
ref = pd.DataFrame({
    "age": np.random.normal(40, 5, 400),
    "income": np.random.normal(3000, 500, 400)
})

cur = pd.DataFrame({
    "age": np.random.normal(25, 6, 400),
    "income": np.random.normal(1200, 300, 400)
})

report = Report(metrics=[DataDriftPreset()])
report.run(reference_data=ref, current_data=cur)
report.save_html('drift_report6.html')

# %% [markdown]
# ## **6. Интерактив: когда дрифт не является проблемой?**
#
# - **Сезонность:** спрос на услуги растёт летом — дрифт естественный.
# - **Промоакции:** временное изменение распределения клиентов.
# - **Новый продукт:** структура данных изменилась, но модель адаптирована.
#
#  **Вывод:**
# не каждый дрифт = деградация.
# важно анализировать контекст и бизнес-метрики.

# %% [markdown]
# ## **7. Интеграция Evidently в CI/CD**
#
# Пример простого шага проверки в GitHub Actions:
#
# ```yaml
# - name: Check for data drift
#   run: |
#     python detect_drift.py

# %% [markdown]
# ---
#
# ```markdown
# ##**Мини-практикум**
#
# 1. Измените только один признак и повторите анализ.
# 2. Сравните отчёт и определите, какие метрики реагируют быстрее.
# 3. Добавьте метрику `TargetDriftPreset()` и оцените, изменилась ли целевая переменная.
# 4. Сохраните HTML-отчёт и прикрепите к отчёту в GitHub.

# %% [markdown]
# ## **9. Итог семинара**
#
# После занятия вы получили:
#
# - отчёт о дрифте данных и целей;
# - навыки интерпретации статистических показателей;
# - шаблон автоматического детектора дрифта для CI/CD;
# - понимание, когда и зачем перезапускать обучение модели.
#
# **Мониторинг дрифта — неотъемлемая часть MLOps:**
# он позволяет поддерживать актуальность модели и предотвращать её деградацию в продакшене.
